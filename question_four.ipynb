# %%
records = [['2014', 'FEMALE', 'USA', 'Abeba', '10', '40'], ['2014', 'FEMALE', 'USA', 'Abaynesh', '27', '23'], 
           ['2014', 'FEMALE', 'USA', 'Abigail', '31', '19'], ['2014', 'MALE','USA', 'Araya', '10', '40'], 
           ['2014', 'MALE', 'USA', 'Abiy', '27', '23'], ['2014', 'MALE', 'USA', 'Ali', '31', '19'], 
           ['2011', 'FEMALE', 'Ethiopia', 'GENET', '13', '75'], ['2014', 'MALE', 'ETHIOPIA', 'Abebe', '10', '40']]

#case insensitive sorting 

#records.sort(key=str.lower) 


student_name = []
for d_name in records:
    if d_name[3]:
        student_name.append(d_name[3])

print(student_name)
#list comprehesion applied 
for x, y in [(x,y) for x in student_name for y in records]:
    print (x, y)
# Out:
# ['Abeba', 'Abaynesh', 'Abigail', 'Araya', 'Abiy', 'Ali', 'GENET', 'Abebe']
# Abeba ['2014', 'FEMALE', 'USA', 'Abeba', '10', '40']
# Abeba ['2014', 'FEMALE', 'USA', 'Abaynesh', '27', '23']
# Abeba ['2014', 'FEMALE', 'USA', 'Abigail', '31', '19']
# Abeba ['2014', 'MALE', 'USA', 'Araya', '10', '40']
# Abeba ['2014', 'MALE', 'USA', 'Abiy', '27', '23']
# Abeba ['2014', 'MALE', 'USA', 'Ali', '31', '19']
# Abeba ['2011', 'FEMALE', 'Ethiopia', 'GENET', '13', '75']
# Abeba ['2014', 'MALE', 'ETHIOPIA', 'Abebe', '10', '40']
# Abaynesh ['2014', 'FEMALE', 'USA', 'Abeba', '10', '40']
# Abaynesh ['2014', 'FEMALE', 'USA', 'Abaynesh', '27', '23']
# Abaynesh ['2014', 'FEMALE', 'USA', 'Abigail', '31', '19']
# Abaynesh ['2014', 'MALE', 'USA', 'Araya', '10', '40']
# Abaynesh ['2014', 'MALE', 'USA', 'Abiy', '27', '23']
# Abaynesh ['2014', 'MALE', 'USA', 'Ali', '31', '19']
# Abaynesh ['2011', 'FEMALE', 'Ethiopia', 'GENET', '13', '75']
# Abaynesh ['2014', 'MALE', 'ETHIOPIA', 'Abebe', '10', '40']
# Abigail ['2014', 'FEMALE', 'USA', 'Abeba', '10', '40']
# Abigail ['2014', 'FEMALE', 'USA', 'Abaynesh', '27', '23']
# Abigail ['2014', 'FEMALE', 'USA', 'Abigail', '31', '19']
# Abigail ['2014', 'MALE', 'USA', 'Araya', '10', '40']
# Abigail ['2014', 'MALE', 'USA', 'Abiy', '27', '23']
# Abigail ['2014', 'MALE', 'USA', 'Ali', '31', '19']
# Abigail ['2011', 'FEMALE', 'Ethiopia', 'GENET', '13', '75']
# Abigail ['2014', 'MALE', 'ETHIOPIA', 'Abebe', '10', '40']
# Araya ['2014', 'FEMALE', 'USA', 'Abeba', '10', '40']
# Araya ['2014', 'FEMALE', 'USA', 'Abaynesh', '27', '23']
# Araya ['2014', 'FEMALE', 'USA', 'Abigail', '31', '19']
# Araya ['2014', 'MALE', 'USA', 'Araya', '10', '40']
# Araya ['2014', 'MALE', 'USA', 'Abiy', '27', '23']
# Araya ['2014', 'MALE', 'USA', 'Ali', '31', '19']
# Araya ['2011', 'FEMALE', 'Ethiopia', 'GENET', '13', '75']
# Araya ['2014', 'MALE', 'ETHIOPIA', 'Abebe', '10', '40']
# Abiy ['2014', 'FEMALE', 'USA', 'Abeba', '10', '40']
# Abiy ['2014', 'FEMALE', 'USA', 'Abaynesh', '27', '23']
# Abiy ['2014', 'FEMALE', 'USA', 'Abigail', '31', '19']
# Abiy ['2014', 'MALE', 'USA', 'Araya', '10', '40']
# Abiy ['2014', 'MALE', 'USA', 'Abiy', '27', '23']
# Abiy ['2014', 'MALE', 'USA', 'Ali', '31', '19']
# Abiy ['2011', 'FEMALE', 'Ethiopia', 'GENET', '13', '75']
# Abiy ['2014', 'MALE', 'ETHIOPIA', 'Abebe', '10', '40']
# Ali ['2014', 'FEMALE', 'USA', 'Abeba', '10', '40']
# Ali ['2014', 'FEMALE', 'USA', 'Abaynesh', '27', '23']
# Ali ['2014', 'FEMALE', 'USA', 'Abigail', '31', '19']
# Ali ['2014', 'MALE', 'USA', 'Araya', '10', '40']
# Ali ['2014', 'MALE', 'USA', 'Abiy', '27', '23']
# Ali ['2014', 'MALE', 'USA', 'Ali', '31', '19']
# Ali ['2011', 'FEMALE', 'Ethiopia', 'GENET', '13', '75']
# Ali ['2014', 'MALE', 'ETHIOPIA', 'Abebe', '10', '40']
# GENET ['2014', 'FEMALE', 'USA', 'Abeba', '10', '40']
# GENET ['2014', 'FEMALE', 'USA', 'Abaynesh', '27', '23']
# GENET ['2014', 'FEMALE', 'USA', 'Abigail', '31', '19']
# GENET ['2014', 'MALE', 'USA', 'Araya', '10', '40']
# GENET ['2014', 'MALE', 'USA', 'Abiy', '27', '23']
# GENET ['2014', 'MALE', 'USA', 'Ali', '31', '19']
# GENET ['2011', 'FEMALE', 'Ethiopia', 'GENET', '13', '75']
# GENET ['2014', 'MALE', 'ETHIOPIA', 'Abebe', '10', '40']
# Abebe ['2014', 'FEMALE', 'USA', 'Abeba', '10', '40']
# Abebe ['2014', 'FEMALE', 'USA', 'Abaynesh', '27', '23']
# Abebe ['2014', 'FEMALE', 'USA', 'Abigail', '31', '19']
# Abebe ['2014', 'MALE', 'USA', 'Araya', '10', '40']
# Abebe ['2014', 'MALE', 'USA', 'Abiy', '27', '23']
# Abebe ['2014', 'MALE', 'USA', 'Ali', '31', '19']
# Abebe ['2011', 'FEMALE', 'Ethiopia', 'GENET', '13', '75']
# Abebe ['2014', 'MALE', 'ETHIOPIA', 'Abebe', '10', '40']
